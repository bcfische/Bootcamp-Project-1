# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
marriage_09_df = pd.read_csv("09_marriage.csv")
marriage_09_df.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label  \
# 0              Id     Id2                 Geography
# 1  0500000US04001   04001    Apache County, Arizona
# 2  0500000US04003   04003   Cochise County, Arizona
# 3  0500000US04005   04005  Coconino County, Arizona
# 4  0500000US04007   04007      Gila County, Arizona
#
#                                    HC01_EST_VC01  \
# 0  Total; Estimate; Population 15 years and over
# 1                                          50927
# 2                                         101971
# 3                                          99605
# 4                                          42073
#
#                                        HC01_MOE_VC01  \
# 0  Total; Margin of Error; Population 15 years an...
# 1                                                102
# 2                                                 72
# 3                                                 85
# 4                                              *****
#
# ...

# %%
marriage_rate_county_09 =  marriage_09_df[["GEO.display-label", "HC02_EST_VC01"]]
marriage_rate_county_09.head()
# Out:
#           GEO.display-label                                      HC02_EST_VC01
# 0                 Geography  Now married (except separated); Estimate; Popu...
# 1    Apache County, Arizona                                               39.3
# 2   Cochise County, Arizona                                               54.5
# 3  Coconino County, Arizona                                               45.8
# 4      Gila County, Arizona                                               49.9

# %%
marriage_10_df = pd.read_csv("10_marriage.csv")
marriage_10_df.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label  \
# 0              Id     Id2                 Geography
# 1  0500000US04001   04001    Apache County, Arizona
# 2  0500000US04003   04003   Cochise County, Arizona
# 3  0500000US04005   04005  Coconino County, Arizona
# 4  0500000US04007   04007      Gila County, Arizona
#
#                                    HC01_EST_VC01  \
# 0  Total; Estimate; Population 15 years and over
# 1                                          51994
# 2                                         104749
# 3                                         105609
# 4                                          43795
#
#                                        HC01_MOE_VC01  \
# 0  Total; Margin of Error; Population 15 years an...
# 1                                                 29
# 2                                                 91
# 3                                                 80
# 4                                              *****
#
# ...

# %%
marriage_rate_county_10 =  marriage_10_df[["GEO.display-label", "HC02_EST_VC01"]]
marriage_rate_county_10.head()
# Out:
#           GEO.display-label                                      HC02_EST_VC01
# 0                 Geography  Now married (except separated); Estimate; Popu...
# 1    Apache County, Arizona                                               38.1
# 2   Cochise County, Arizona                                               54.4
# 3  Coconino County, Arizona                                               43.7
# 4      Gila County, Arizona                                               51.2

# %%
marriage_11_df = pd.read_csv("11_marriage.csv")
marriage_11_df.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label  \
# 0              Id     Id2                 Geography
# 1  0500000US04001   04001    Apache County, Arizona
# 2  0500000US04003   04003   Cochise County, Arizona
# 3  0500000US04005   04005  Coconino County, Arizona
# 4  0500000US04007   04007      Gila County, Arizona
#
#                                    HC01_EST_VC01  \
# 0  Total; Estimate; Population 15 years and over
# 1                                          52644
# 2                                         105812
# 3                                         106937
# 4                                          43970
#
#                                        HC01_MOE_VC01  \
# 0  Total; Margin of Error; Population 15 years an...
# 1                                                 54
# 2                                                 90
# 3                                                107
# 4                                                 81
#
# ...

# %%
marriage_rate_county_11 =  marriage_11_df[["GEO.display-label", "HC02_EST_VC01"]]
marriage_rate_county_11.head()
# Out:
#           GEO.display-label                                      HC02_EST_VC01
# 0                 Geography  Now married (except separated); Estimate; Popu...
# 1    Apache County, Arizona                                               36.9
# 2   Cochise County, Arizona                                               52.8
# 3  Coconino County, Arizona                                               42.7
# 4      Gila County, Arizona                                               51.1

# %%
marriage_12_df = pd.read_csv("12_marriage.csv")
marriage_12_df.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label  \
# 0              Id     Id2                 Geography
# 1  0500000US04001   04001    Apache County, Arizona
# 2  0500000US04003   04003   Cochise County, Arizona
# 3  0500000US04005   04005  Coconino County, Arizona
# 4  0500000US04007   04007      Gila County, Arizona
#
#                                    HC01_EST_VC01  \
# 0  Total; Estimate; Population 15 years and over
# 1                                          53250
# 2                                         106436
# 3                                         108108
# 4                                          44135
#
#                                        HC01_MOE_VC01  \
# 0  Total; Margin of Error; Population 15 years an...
# 1                                                 97
# 2                                                104
# 3                                                 80
# 4                                                 98
#
# ...

# %%
marriage_rate_county_12 =  marriage_12_df[["GEO.display-label", "HC02_EST_VC01"]]
marriage_rate_county_12.head()
# Out:
#           GEO.display-label                                      HC02_EST_VC01
# 0                 Geography  Now married (except separated); Estimate; Popu...
# 1    Apache County, Arizona                                               36.5
# 2   Cochise County, Arizona                                               51.4
# 3  Coconino County, Arizona                                               42.5
# 4      Gila County, Arizona                                               50.8

# %%
marriage_13_df = pd.read_csv("13_marriage.csv")
marriage_13_df.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label  \
# 0              Id     Id2                 Geography
# 1  0500000US04001   04001    Apache County, Arizona
# 2  0500000US04003   04003   Cochise County, Arizona
# 3  0500000US04005   04005  Coconino County, Arizona
# 4  0500000US04007   04007      Gila County, Arizona
#
#                                    HC01_EST_VC01  \
# 0  Total; Estimate; Population 15 years and over
# 1                                          53830
# 2                                         106335
# 3                                         109150
# 4                                          44101
#
#                                        HC01_MOE_VC01  \
# 0  Total; Margin of Error; Population 15 years an...
# 1                                                122
# 2                                                 96
# 3                                                165
# 4                                                 64
#
# ...

# %%
marriage_rate_county_13 =  marriage_13_df[["GEO.display-label", "HC02_EST_VC01"]]
marriage_rate_county_13.head()
# Out:
#           GEO.display-label                                      HC02_EST_VC01
# 0                 Geography  Now married (except separated); Estimate; Popu...
# 1    Apache County, Arizona                                               35.3
# 2   Cochise County, Arizona                                               50.4
# 3  Coconino County, Arizona                                               42.2
# 4      Gila County, Arizona                                               51.2

# %%
marriage_14_df = pd.read_csv("14_marriage.csv")
marriage_14_df.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label  \
# 0              Id     Id2                 Geography
# 1  0500000US04001   04001    Apache County, Arizona
# 2  0500000US04003   04003   Cochise County, Arizona
# 3  0500000US04005   04005  Coconino County, Arizona
# 4  0500000US04007   04007      Gila County, Arizona
#
#                                    HC01_EST_VC01  \
# 0  Total; Estimate; Population 15 years and over
# 1                                          54145
# 2                                         105930
# 3                                         110505
# 4                                          44110
#
#                                        HC01_MOE_VC01  \
# 0  Total; Margin of Error; Population 15 years an...
# 1                                                 68
# 2                                                 88
# 3                                                150
# 4                                                 58
#
# ...

# %%
marriage_rate_county_14 =  marriage_14_df[["GEO.display-label", "HC02_EST_VC01"]]
marriage_rate_county_14.head()
# Out:
#           GEO.display-label                                      HC02_EST_VC01
# 0                 Geography  Now married (except separated); Estimate; Popu...
# 1    Apache County, Arizona                                               34.7
# 2   Cochise County, Arizona                                               50.5
# 3  Coconino County, Arizona                                               41.2
# 4      Gila County, Arizona                                               50.7

# %%
marriage_15_df = pd.read_csv("15_marriage.csv")
marriage_15_df.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label  \
# 0              Id     Id2                 Geography
# 1  0500000US04001   04001    Apache County, Arizona
# 2  0500000US04003   04003   Cochise County, Arizona
# 3  0500000US04005   04005  Coconino County, Arizona
# 4  0500000US04007   04007      Gila County, Arizona
#
#                                    HC01_EST_VC01  \
# 0  Total; Estimate; Population 15 years and over
# 1                                          54416
# 2                                         105171
# 3                                         111742
# 4                                          44091
#
#                                        HC01_MOE_VC01  \
# 0  Total; Margin of Error; Population 15 years an...
# 1                                                 71
# 2                                                130
# 3                                                154
# 4                                                 72
#
# ...

# %%
marriage_rate_county_15 =  marriage_15_df[["GEO.display-label", "HC02_EST_VC01"]]
marriage_rate_county_15.head()
# Out:
#           GEO.display-label                                      HC02_EST_VC01
# 0                 Geography  Now married (except separated); Estimate; Popu...
# 1    Apache County, Arizona                                               34.8
# 2   Cochise County, Arizona                                               50.4
# 3  Coconino County, Arizona                                               41.2
# 4      Gila County, Arizona                                               50.9

# %%
marriage_16_df = pd.read_csv("16_marriage.csv")
marriage_16_df.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label  \
# 0              Id     Id2                 Geography
# 1  0500000US04001   04001    Apache County, Arizona
# 2  0500000US04003   04003   Cochise County, Arizona
# 3  0500000US04005   04005  Coconino County, Arizona
# 4  0500000US04007   04007      Gila County, Arizona
#
#                                    HC01_EST_VC01  \
# 0  Total; Estimate; Population 15 years and over
# 1                                          54979
# 2                                         104355
# 3                                         113254
# 4                                          44123
#
#                                        HC01_MOE_VC01  \
# 0  Total; Margin of Error; Population 15 years an...
# 1                                                 69
# 2                                                 41
# 3                                                146
# 4                                                 81
#
# ...

# %%
marriage_rate_county_16 =  marriage_16_df[["GEO.display-label", "HC02_EST_VC01"]]
marriage_rate_county_16.head()
# Out:
#           GEO.display-label                                      HC02_EST_VC01
# 0                 Geography  Now married (except separated); Estimate; Popu...
# 1    Apache County, Arizona                                               34.9
# 2   Cochise County, Arizona                                               50.3
# 3  Coconino County, Arizona                                               40.5
# 4      Gila County, Arizona                                               51.0

# %%
marriage_17_df = pd.read_csv("17_marriage.csv")
marriage_17_df.head()
# Out:
#            GEO.id GEO.id2         GEO.display-label  \
# 0              Id     Id2                 Geography
# 1  0500000US04001   04001    Apache County, Arizona
# 2  0500000US04003   04003   Cochise County, Arizona
# 3  0500000US04005   04005  Coconino County, Arizona
# 4  0500000US04007   04007      Gila County, Arizona
#
#                                    HC01_EST_VC01  \
# 0  Total; Estimate; Population 15 years and over
# 1                                          54926
# 2                                         103124
# 3                                         114041
# 4                                          44062
#
#                                        HC01_MOE_VC01  \
# 0  Total; Margin of Error; Population 15 years an...
# 1                                                 78
# 2                                                 86
# 3                                                184
# 4                                                 93
#
# ...

# %%
marriage_rate_county_17 =  marriage_17_df[["GEO.display-label", "HC02_EST_VC01"]]
marriage_rate_county_17.head()
# Out:
#           GEO.display-label                                      HC02_EST_VC01
# 0                 Geography  Now married (except separated); Estimate; Popu...
# 1    Apache County, Arizona                                               34.7
# 2   Cochise County, Arizona                                               52.0
# 3  Coconino County, Arizona                                               39.5
# 4      Gila County, Arizona                                               51.3
